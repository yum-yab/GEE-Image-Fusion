# %%
import ee
from GEE_ImageFusion import *
import geemap

# %%
ee.Authenticate()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# True

# %%
ee.Initialize(project='landsat-fusion')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# to export the images to an asset we need the path to the assets folder
path = "projects/landsat-fusion/assets/testruns/"
scene_name = "aoi1_test"
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
startDate = "2005-01-01"
endDate = "2005-09-01"
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# fix row and path for satellite

wrs_row = 24
wrs_path = 195
# region of aoi 1 of max paper
# region = ee.Geometry.BBox(9.3691495, 50.8256345, 9.5121092, 50.9150223)

# Define a small box around the original point for faster testing
lon, lat = 9.85958, 51.89876
w = 0.04  # half-width of the box in degrees (~1.1km)
region = ee.Geometry.Polygon(
    [[[lon - w, lat - w],
      [lon + w, lat - w],
      [lon + w, lat + w],
      [lon - w, lat + w]]])
# region= ee.Geometry.Point([9.859583197729028,51.898764158694334])
region.bounds().getInfo()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# {'geodesic': False,
#  'type': 'Polygon',
#  'coordinates': [[[9.819580000000002, 51.85875999999998],
#    [9.89958, 51.85875999999998],
#    [9.89958, 51.938766777537396],
#    [9.819580000000002, 51.938766777537396],
#    [9.819580000000002, 51.85875999999998]]]}

# %%
point = ee.Geometry.Point([9.859583197729028,51.898764158694334])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# commonBandNames = ee.List(["blue", "green", "red", "nir", "swir1", "swir2"])
# commonBandNames = ee.List(["blue", "green", "red", "nir", "swir1"])
commonBandNames = ee.List(["blue", "green", "red"])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
landsatCollection = "LANDSAT/LT05/C02/T1_L2"
modisCollection = "MODIS/061/MCD43A4"
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# bandNamesLandsat = ee.List(
#     ["blue", "green", "red", "nir", "swir1", "swir2"]
# )
# bandNamesLandsat = ee.List(
#     ["blue", "green", "red", "nir", "swir1"]
# )
bandNamesLandsat = ee.List(
    ["blue", "green", "red"]
)
# landsatBands = ee.List([0, 1, 2, 3, 4, 5])
# landsatBands = ee.List([0, 1, 2, 3, 4])
landsatBands = ee.List([0, 1, 2])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# modis band names
bandNamesModis = ee.List(["blue", "green", "red", "nir", "swir1"])
# bandNamesModis = bandNamesLandsat
# modisBands = ee.List([2, 3, 0, 1, 5, 6])
modisBands = ee.List([2, 3, 0, 1, 5])
# modisBands = ee.List([2, 3, 0])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# radius of moving window
# Note: Generally, larger windows are better but as the window size increases,
# so does the memory requirement and we quickly will surpass the memory
# capacity of a single node (in testing 13 was max size for single band, and
# 10 was max size for up to 6 bands)
kernelRadius = ee.Number(10)
kernel = ee.Kernel.square(kernelRadius)
numPixels = kernelRadius.add(kernelRadius.add(1)).pow(2)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
kernel.getInfo()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# {'type': 'Kernel.square',
#  'radius': 10,
#  'center': [10, 10],
#  'weights': '\n  [0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248]\n  [0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248]\n  [0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248]\n  [0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248]\n  [0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248]\n  [0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248]\n  [0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248]\n  [0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248]\n  [0.0022675736961451248, 0.0022675736961451248, 0.0022675736961451248, 0.002267573696145 ...

# %%
coverClasses = 7
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# sorted, filtered, paired image retrieval

paired = getPaired(
    startDate = startDate,
    endDate = endDate,
    landsatCollection = landsatCollection,
    landsatBands = landsatBands,
    bandNamesLandsat = bandNamesLandsat,
    modisCollection = modisCollection,
    modisBands = modisBands,
    bandNamesModis = bandNamesModis,
    commonBandNames = commonBandNames,
    region = region,
    WRS_PATH = wrs_path,
    WRS_ROW = wrs_row,
    cloud_cover_limit = 20,    
    skip_masking = False,
)

# paired = getPaired(
#     startDate,
#     endDate,
#     landsatCollection,
#     landsatBands,
#     bandNamesLandsat,
#     modisCollection,
#     modisBands,
#     bandNamesModis,
#     commonBandNames,
#     region
# )

landsat1, modis_paired, modis_unpaired = paired

print("Size of l1:", landsat1.size().getInfo())
print("Size of modis(paired):", modis_paired.size().getInfo())
print("Size of modis(unpaired):", modis_unpaired.size().getInfo())

subs = makeSubcollections(paired)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Size of l1: 2
# Size of modis(paired): 2
# Size of modis(unpaired): 241

# %%
num_lists = subs.length().getInfo()

print(f"Length of Subcollections: {num_lists}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Length of Subcollections: 1

# %%
testsub = subs.get(0)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# ee.List(ee.List(testsub).get(2)).length().getInfo()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# ee.List(ee.List(testsub).get(0)).length().getInfo()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# ee.List(ee.List(testsub).get(1)).length().getInfo()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
landsat_t01 = ee.List(ee.List(testsub).get(0))
modis_t01 = ee.List(ee.List(testsub).get(1))
modis_tp = ee.List(ee.List(testsub).get(2))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# ee.Image(modis_t01.get(0)).bandNames().size().getInfo()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# ee.Image(modis_tp.map(lambda img: ee.Image(img).resample('bicubic')).get(0)).geometry().bounds()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# resampled_landsat0 = ee.Image(landsat_t01.map(lambda img: ee.Image(img).resample('bicubic')).get(0))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# resampled_landsat0.projection().getInfo()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# resampled_modis = ee.Image(modis_tp.map(lambda img: ee.Image(img).resample('bicubic')).get(0))

# resampled_modis.projection().getInfo()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# resampled_landsat0.bandNames().getInfo()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# resampled_modis.bandNames().getInfo()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# resampled_modis.clip(region).geometry().getInfo()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# resampled_landsat0.geometry().getInfo()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# resampled_modis.clip(region).register(resampled_landsat0, maxOffset=ee.Number(150.0), stiffness=ee.Number(7.0)).bandNames().getInfo()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# register images
# landsat_t01, modis_t01, modis_tp = registerImages(landsat_t01, modis_t01, modis_tp, clip_modis=region)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# ee.Image(modis_t01.get(0)).bandNames().size().getInfo()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
ee.Image(landsat_t01.get(0)).bandNames().getInfo()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['blue', 'green', 'red']

# %%
ee.Image(landsat_t01.get(1)).reduceRegion(reducer=ee.Reducer.stdDev(),
                                              bestEffort=True,
                                              maxPixels=ee.Number(1e6)).getInfo()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# {'blue': 0.01917057460179315,
#  'green': 0.02840167747433769,
#  'red': 0.042502956339794014}

# %%
doys = landsat_t01.map(lambda img: ee.String(ee.Image(img).get("DOY")).cat("_"))
maskedLandsat, pixPositions, pixBN = prepLandsat(
    landsat_t01, kernel, numPixels, commonBandNames, doys, coverClasses, region
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
pix_bn_cli = pixBN.getInfo()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
import numpy as np


np.array(pix_bn_cli).size
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 2646

# %%
# landsat_t01.map(
#     lambda img: ee.Image(img).neighborhoodToBands(kernel)
# ).length().getInfo()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
maskedLandsat.length().getInfo()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 441

# %%
# prep modis imagery (mask and format)
modSorted_t01, modSorted_tp = prepMODIS(
    modis_t01, modis_tp, kernel, numPixels, commonBandNames, pixBN
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# calculate spectral distance
specDist = calcSpecDist(maskedLandsat, modSorted_t01, numPixels, pixPositions)

# calculate spatial distance
spatDist = calcSpatDist(pixPositions)

# calculate weights from the spatial and spectral distances
weights = calcWeight(spatDist, specDist)

# calculate the conversion coefficients
coeffs = calcConversionCoeff(
    maskedLandsat, modSorted_t01, doys, numPixels, commonBandNames
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# predict all modis images in modis tp collection
prediction = modSorted_tp.map(
    lambda image: predictLandsat(
        landsat_t01,
        modSorted_t01,
        doys,
        ee.List(image),
        weights,
        coeffs,
        commonBandNames,
        numPixels,
    )
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
ee.Image(prediction.get(0)).bandNames().getInfo()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['blue', 'green', 'red']

# %%
test_img = ee.Image(prediction.get(0))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
task = ee.batch.Export.image.toDrive(
    image=test_img,
    description='ESTARFM_TESTAREA_CALCULATION',
    folder='ee_data',  # The folder name in your Google Drive
    fileNamePrefix='estarfm_2005_testarea',
    scale=30,                     # Adjust scale based on your data (e.g., 30 for Landsat)
    region=test_img.geometry() # Or define a custom ee.Geometry
)

# 3. Start the task
task.start()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
for i in range(0, num_lists):
    # determine the number of modis images between pairs
    num_imgs = ee.List(ee.List(subs.get(i)).get(2)).length()

    # determine the remainder of images, if not groups of 10
    remaining = num_imgs.mod(10)

    # create sequence of starting indices for modis images
    index_seq = ee.List.sequence(0, num_imgs.subtract(remaining), 10)

    # images to be grouped and predicted
    subList = ee.List(ee.List(subs.get(i)).get(2))

    # loop through indices predicting in batches of 10
    for x in range(0, index_seq.length().getInfo()):
        # starting index
        start = ee.Number(index_seq.get(x))

        # ending index
        end = ee.Algorithms.If(start.add(10).gt(num_imgs), num_imgs, start.add(10))

        # group of images to predict
        pred_group = subList.slice(start, end)
        landsat_t01 = ee.List(ee.List(subs.get(i)).get(0))
        modis_t01 = ee.List(ee.List(subs.get(i)).get(1))
        modis_tp = pred_group

        # get the start and end day values and year for the group to use
        # to label the file when exported to asset
        startDay = ee.Number.parse(ee.ImageCollection(pred_group).first().get("DOY"))
        endDay = ee.Number.parse(
            ee.ImageCollection(pred_group)
            .sort("system:time_start", False)
            .first()
            .get("DOY")
        )
        year = ee.Date(
            ee.ImageCollection(pred_group)
            .sort("system:time_start", False)
            .first()
            .get("system:time_start")
        ).format("Y")

        # start and end day of year
        doys = landsat_t01.map(lambda img: ee.String(ee.Image(img).get("DOY")).cat("_"))

        # register images
        landsat_t01, modis_t01, modis_tp = registerImages(
            landsat_t01, modis_t01, modis_tp
        )

        # prep landsat imagery (mask and format)
        maskedLandsat, pixPositions, pixBN = prepLandsat(
            landsat_t01, kernel, numPixels, commonBandNames, doys, coverClasses, region
        )

        # prep modis imagery (mask and format)
        modSorted_t01, modSorted_tp = prepMODIS(
            modis_t01, modis_tp, kernel, numPixels, commonBandNames, pixBN
        )

        # calculate spectral distance
        specDist = calcSpecDist(maskedLandsat, modSorted_t01, numPixels, pixPositions)

        # calculate spatial distance
        spatDist = calcSpatDist(pixPositions)

        # calculate weights from the spatial and spectral distances
        weights = calcWeight(spatDist, specDist)

        # calculate the conversion coefficients
        coeffs = calcConversionCoeff(
            maskedLandsat, modSorted_t01, doys, numPixels, commonBandNames
        )

        # predict all modis images in modis tp collection
        prediction = modSorted_tp.map(
            lambda image: predictLandsat(
                landsat_t01,
                modSorted_t01,
                doys,
                ee.List(image),
                weights,
                coeffs,
                commonBandNames,
                numPixels,
            )
        )

        # create a list of new band names to apply to the multiband ndvi image
        # NOTE: cant export with names starting with 0
        preds = ee.ImageCollection(prediction).toBands()
        dates = modis_tp.map(lambda img: ee.Image(img).get("system:time_start"))
        predNames = (
            ee.List.sequence(0, prediction.length().subtract(1))
            .map(
                lambda i: commonBandNames.map(
                    lambda name: ee.String(name).cat(
                        ee.String(ee.Number(dates.get(i)).format())
                    )
                )
            )
            .flatten()
        )

        # export all predictions as a single multiband image
        # each band name corresponds to the timestamp for the image
        task = ee.batch.Export.image.toAsset(
            image=preds.rename(predNames).multiply(10000).toInt16(),
            description=ee.String(scene_name)
            .cat(year)
            .cat("_")
            .cat(startDay.format())
            .cat("_")
            .cat(endDay.format())
            .getInfo(),
            assetId=ee.String(path)
            .cat(ee.String(scene_name))
            .cat(year)
            .cat("_")
            .cat(startDay.format())
            .cat("_")
            .cat(endDay.format())
            .getInfo(),
            region=region,
            scale=30,
            crs='EPSG:32632',
        )

        task.start()
